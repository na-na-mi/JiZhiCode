# %%
import pandas as pd
with open("file.txt","r", encoding='UTf-8') as str:
    data = str.read()
    data.strip(" ")
print(data)
# Out:
# 当 今世 界 能源 缺 乏、原 料上 涨 、工 人短 缺 ，国际 市场 竞 争日 趋 剧烈 ，公 害问 题 普遍 受 到注 意 。借
# 助 计算 机 科学 技 术 ，工 业工 程 日益 发 展成 为 一门 充
# 满 活力 的 专业 化 学科 ，利 用它 能 够解 决 那些 存 在于
# 企 业经 营 中大 而 复杂 的 问题 。
# 这 个趋 势 无疑 将 是我 国 的工 业 工程 发 展的 方 向。 随 着工 业 增长 的 复杂 性
# 和 能源 的 短缺 ， 服务 业 以及 政 府部 门 为工 业 工程 师 们提 供 了比 以 前任 何 时候
# 都 更为 广 阔的 就 业机 会 。工 业 工程 是 将工 程 技术 与 管理 结 合起 来 ，同 时 具备
# 工 程技 术 与管 理 两方 面 的知 识 和技 能
# 近 年来 ， 中国 的 经济 发 展已 由 高速 增 长阶 段 逐步 转 入高 质 量发 展 阶段 ，
# 政 府更 加 关注 于 优化 经 济结 构 、转 换 增长 动 力。 制 造业 是 供给 侧 结构 性 改革
# 的 主要 领 域， 尽 管制 造 业增 加 值在 全 国 GDP 总 量中 的 比重 呈 下降 态 势， 但 以
# 制 造业 为 代表 的 实体 经 济才 是 中国 经 济高 质 量发 展 的核 心 支撑 力 量。
# 2015-2016 年 ，中 国制 造 业增 加 值的 同 比增 速 仅为 3.5%和 5.9%，原 料、土 地 、
# 人 力资 源 等生 产 要素 成 本的 不 断上 涨 使制 造 业本 就 不高 的 利润 率 很难 提 升。
# 提 高质 量 效益 、 转变 生 产方 式 是中 国 制造 业 必须 要 解决 的 问题 ， 而工业工程师 的改 善 工业 生 产结 构 ，优 化 生产 流 程， 形 成自动化产业线的 职 责也开始变得 重要 起 来了 。
